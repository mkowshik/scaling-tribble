# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# %%
path = '/Users/Manoj/Dropbox/Thesis/Data/REBUILD data/Subjects/PHYSICS.tab'
data = pd.read_table(path)

# %%
# ##Using group by
# gender = data[['male','female']].groupby(data['catalognbr']==140)
# gender.plot()

# #gender = data[[data['catalognbr']==140,'male','female']]
# gender = data.groupby([data['catalognbr'],data['male'],data['female']])
# #gender.plot()

# %%
number = 235

# %% [markdown]
# ## All time and all terms

# %%
Class = data.ix[data['catalognbr']==number]

#Enrollment
Class['total_students'].plot(title = "Enrollment in Physics 140 over time. All Terms.")

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=15,alpha=.5)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# -c:11: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.py:1926: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   self.where(-key, value, inplace=True)
# mean =
# male      0.473961
# female    0.526039
# dtype: float64
# *Mean Grades*:
# mean_grade_male      3.052277
# mean_grade_female    2.894305
# dtype: float64
# Male Grade mean = 3.05227653846
# Male Grade std = 0.203462067442
# Female Grade mean = 2.89430515385
# Female Grade std = 0.186547775948
# Average Difference Across time: 0.157971384615
# STD  0.105605424173

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=25, alpha =.5)
fgpa.hist(bins=25, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()



#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=25,alpha=.5)
fgpa.hist(bins=25,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.31509523077
# Male GPA std = 0.0698142436018
# Female GPA mean = 3.36343415385
# Female GPA std = 0.049845443827
# Male GPA mean = 3.33614953846
# Male GPA std = 0.0619193172626
# Female GPA mean = 3.39573446154
# Female GPA std = 0.0471845700956

# %%
##Percentage of women in class vs. performance

x = gender['female']
y = gfemale.fillna(0)

plt.plot(x,y,'.')

from scipy import stats
a= stats.linregress(x,y)
print "slope: ", a[0]
print "intercept: ", a[1]
print "r - value: ", a[2]
print "p - value: ", a[3]
print "stderr: ", a[4]
# Out:
# slope:  0.288164348423
# intercept:  2.74271942162
# r - value:  0.0819830481395
# p - value:  0.790041246827
# stderr:  1.056222522

# %% [markdown]
# ### SPRING TERM

# %%
#Spring Only
spring = data.ix[data['termdescrshort'].str.contains("SP")]
Class = spring.ix[spring['catalognbr']==number]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =25)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.421435
# female    0.578565
# dtype: float64
# *Mean Grades*:
# mean_grade_male      3.074025
# mean_grade_female    2.970647
# dtype: float64
# Male Grade mean = 3.074025
# Male Grade std = 0.357106533854
# Female Grade mean = 2.97064666667
# Female Grade std = 0.299712859187
# Average Difference Across time: 0.103378333333
# STD  0.128619320109

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .3)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5)
fgpa.hist(bins=15,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.27219466667
# Male GPA std = 0.125475303217
# Female GPA mean = 3.33456
# Female GPA std = 0.0648834401061
# Male GPA mean = 3.29515066667
# Male GPA std = 0.101536429198
# Female GPA mean = 3.35683233333
# Female GPA std = 0.0499625705537

# %% [markdown]
# ### FALL AND WINTER

# %%
#Fall Winter only
FW = data.ix[data['termdescrshort'].str.contains("FA|WN")]
FW1 = FW.ix[FW['catalognbr'] == number]

thr = 350 #threshold for steady enrollment
Class = FW1.ix[FW1['total_students'] > thr]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist(alpha=.5)
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.502298
# female    0.497702
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.894471
# mean_grade_female    2.773381
# dtype: float64
# Male Grade mean = 2.8944715
# Male Grade std = 0.143178516589
# Female Grade mean = 2.7733805
# Female Grade std = 0.173410159911
# Average Difference Across time: 0.121091
# STD  0.0302316433228

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5,label='Male')
fgpa.hist(bins=15,alpha=.5,label='Male')
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.3289775
# Male GPA std = 0.0427552115245
# Female GPA mean = 3.374729
# Female GPA std = 0.0332920014719
# Male GPA mean = 3.358258
# Male GPA std = 0.0370382531986
# Female GPA mean = 3.4120725
# Female GPA std = 0.0170858211538
