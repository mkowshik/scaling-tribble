# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# %%
path = '/Users/Manoj/Dropbox/Thesis/Data/REBUILD data/Subjects/BIOLOGY.tab'
data = pd.read_table(path)

# %%
number = 171

# %% [markdown]
# ## All time and all terms

# %%
Class = data.ix[data['catalognbr']==number]

#Enrollment
Class['total_students'].plot(title = "Enrollment in Physics 140 over time. All Terms.")

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=15,alpha=.5)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.387018
# female    0.612982
# dtype: float64
# -c:11: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.py:1926: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   self.where(-key, value, inplace=True)
# *Mean Grades*:
# mean_grade_male      2.89964
# mean_grade_female    2.83125
# dtype: float64
# Male Grade mean = 2.89963956522
# Male Grade std = 0.159699966712
# Female Grade mean = 2.83125026087
# Female Grade std = 0.216870676729
# Average Difference Across time: 0.0683893043478
# STD  0.258474202584

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=25, alpha =.5)
fgpa.hist(bins=25, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()



#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=25,alpha=.5)
fgpa.hist(bins=25,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.02864809412
# Male GPA std = 0.241493288517
# Female GPA mean = 3.0327402619
# Female GPA std = 0.240622581147
# Male GPA mean = 3.06464950588
# Male GPA std = 0.238669052839
# Female GPA mean = 3.09653969048
# Female GPA std = 0.250212433678

# %%
##Percentage of women in class vs. performance

x = gender['female']
y = gfemale.fillna(0)

plt.plot(x,y,'.')

from scipy import stats
a= stats.linregress(x,y)
print "slope: ", a[0]
print "intercept: ", a[1]
print "r - value: ", a[2]
print "p - value: ", a[3]
print "stderr: ", a[4]
# Out:
# slope:  0.634975602999
# intercept:  2.27703381556
# r - value:  0.173290147183
# p - value:  0.108464358005
# stderr:  0.391428978422

# %% [markdown]
# ### SPRING TERM

# %%
#Spring Only
spring = data.ix[data['termdescrshort'].str.contains("SP")]
Class = spring.ix[spring['catalognbr']==number]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =25)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.375801
# female    0.624199
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.900119
# mean_grade_female    3.003099
# dtype: float64
# Male Grade mean = 2.90011883333
# Male Grade std = 0.152703956228
# Female Grade mean = 3.00309916667
# Female Grade std = 0.261856543521
# Average Difference Across time: -0.102980333333
# STD  0.36526834596

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .3)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5)
fgpa.hist(bins=15,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 2.95704683333
# Male GPA std = 0.169685925489
# Female GPA mean = 3.07780033333
# Female GPA std = 0.0750396638923
# Male GPA mean = 2.95229933333
# Male GPA std = 0.17540778013
# Female GPA mean = 3.0914445
# Female GPA std = 0.0622553937896

# %% [markdown]
# ### FALL AND WINTER

# %%
#Fall Winter only
FW = data.ix[data['termdescrshort'].str.contains("FA|WN")]
FW1 = FW.ix[FW['catalognbr'] == number]

thr = 350 #threshold for steady enrollment
Class = FW1.ix[FW1['total_students'] > thr]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist(alpha=.5)
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.403325
# female    0.596675
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.839906
# mean_grade_female    2.742421
# dtype: float64
# Male Grade mean = 2.83990576923
# Male Grade std = 0.0886532023459
# Female Grade mean = 2.74242115385
# Female Grade std = 0.0789305946416
# Average Difference Across time: 0.0974846153846
# STD  0.116191111567

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5,label='Male')
fgpa.hist(bins=15,alpha=.5,label='Male')
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.14598584615
# Male GPA std = 0.052441155997
# Female GPA mean = 3.17080384615
# Female GPA std = 0.0341342146969
# Male GPA mean = 3.20533692308
# Male GPA std = 0.0501962772781
# Female GPA mean = 3.25399276923
# Female GPA std = 0.0358393203297

# %%
8
# Out:
# 8
