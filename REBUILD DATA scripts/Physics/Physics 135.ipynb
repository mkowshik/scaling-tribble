# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# %%
path = '/Users/Manoj/Dropbox/Thesis/Data/REBUILD data/Subjects/PHYSICS.tab'
data = pd.read_table(path)

# %%
# ##Using group by
# gender = data[['male','female']].groupby(data['catalognbr']==140)
# gender.plot()

# #gender = data[[data['catalognbr']==140,'male','female']]
# gender = data.groupby([data['catalognbr'],data['male'],data['female']])
# #gender.plot()

# %%
number = 135

# %% [markdown]
# ## All time and all terms

# %%
Class = data.ix[data['catalognbr']==number]

#Enrollment
Class['total_students'].plot(title = "Enrollment in Physics 140 over time. All Terms.")

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=15,alpha=.5)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.443332
# female    0.556668
# dtype: float64
# -c:11: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.py:1926: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   self.where(-key, value, inplace=True)
# *Mean Grades*:
# mean_grade_male      3.224712
# mean_grade_female    3.047177
# dtype: float64
# Male Grade mean = 3.22471157143
# Male Grade std = 0.287068465503
# Female Grade mean = 3.04717671429
# Female Grade std = 0.227411759045
# Average Difference Across time: 0.177534857143
# STD  0.15688770766

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=25, alpha =.5)
fgpa.hist(bins=25, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()



#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=25,alpha=.5)
fgpa.hist(bins=25,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.32410485714
# Male GPA std = 0.108306214688
# Female GPA mean = 3.33891857143
# Female GPA std = 0.0689790488255
# Male GPA mean = 3.3393855
# Male GPA std = 0.095603405121
# Female GPA mean = 3.36759421429
# Female GPA std = 0.0645546530435

# %%
##Percentage of women in class vs. performance

x = gender['female']
y = gfemale.fillna(0)

plt.plot(x,y,'.')

from scipy import stats
a= stats.linregress(x,y)
print "slope: ", a[0]
print "intercept: ", a[1]
print "r - value: ", a[2]
print "p - value: ", a[3]
print "stderr: ", a[4]
# Out:
# slope:  0.867332109944
# intercept:  2.56436065853
# r - value:  0.202081880306
# p - value:  0.488418515112
# stderr:  1.21342689558

# %% [markdown]
# ### SPRING TERM

# %%
#Spring Only
spring = data.ix[data['termdescrshort'].str.contains("SP")]
Class = spring.ix[spring['catalognbr']==number]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =25)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.397706
# female    0.602294
# dtype: float64
# *Mean Grades*:
# mean_grade_male      3.038365
# mean_grade_female    2.838349
# dtype: float64
# Male Grade mean = 3.038365
# Male Grade std = 0.326433874788
# Female Grade mean = 2.83834933333
# Female Grade std = 0.0809540404509
# Average Difference Across time: 0.200015666667
# STD  0.25728466137

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .3)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5)
fgpa.hist(bins=15,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.22787166667
# Male GPA std = 0.0494341265963
# Female GPA mean = 3.25483933333
# Female GPA std = 0.0416867701835
# Male GPA mean = 3.25819833333
# Male GPA std = 0.00829676384726
# Female GPA mean = 3.290252
# Female GPA std = 0.060518820238

# %% [markdown]
# ### FALL AND WINTER

# %%
#Fall Winter only
FW = data.ix[data['termdescrshort'].str.contains("FA|WN")]
FW1 = FW.ix[FW['catalognbr'] == number]

thr = 200 #threshold for steady enrollment
Class = FW1.ix[FW1['total_students'] > thr]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist(alpha=.5)
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.449047
# female    0.550953
# dtype: float64
# *Mean Grades*:
# mean_grade_male      3.184796
# mean_grade_female    3.066721
# dtype: float64
# Male Grade mean = 3.18479571429
# Male Grade std = 0.287376590099
# Female Grade mean = 3.06672085714
# Female Grade std = 0.246518766244
# Average Difference Across time: 0.118074857143
# STD  0.0489438794384

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5,label='Male')
fgpa.hist(bins=15,alpha=.5,label='Male')
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.29718142857
# Male GPA std = 0.078636662963
# Female GPA mean = 3.34641814286
# Female GPA std = 0.0541902729754
# Male GPA mean = 3.30897357143
# Male GPA std = 0.0629075872262
# Female GPA mean = 3.375057
# Female GPA std = 0.0449726372476
