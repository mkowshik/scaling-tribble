# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# %%
path = '/Users/Manoj/Dropbox/Thesis/Data/REBUILD data/Subjects/PHYSICS.tab'
data = pd.read_table(path)

# %%
# ##Using group by
# gender = data[['male','female']].groupby(data['catalognbr']==140)
# gender.plot()

# #gender = data[[data['catalognbr']==140,'male','female']]
# gender = data.groupby([data['catalognbr'],data['male'],data['female']])
# #gender.plot()

# %%
number = 240

# %% [markdown]
# ## All time and all terms

# %%
Class = data.ix[data['catalognbr']==number]

#Enrollment
Class['total_students'].plot(title = "Enrollment in Physics 140 over time. All Terms.")

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=15,alpha=.5)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.745314
# female    0.254686
# dtype: float64
# -c:11: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.py:1926: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   self.where(-key, value, inplace=True)
# *Mean Grades*:
# mean_grade_male      2.812250
# mean_grade_female    2.626034
# dtype: float64
# Male Grade mean = 2.81225035165
# Male Grade std = 0.341245088603
# Female Grade mean = 2.62603447059
# Female Grade std = 0.455398575062
# Average Difference Across time: 0.167644702381
# STD  0.537855399175

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=25, alpha =.5)
fgpa.hist(bins=25, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()



#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=25,alpha=.5)
fgpa.hist(bins=25,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.03360748352
# Male GPA std = 0.255286809808
# Female GPA mean = 3.08312917647
# Female GPA std = 0.231375214079
# Male GPA mean = 3.05512842857
# Male GPA std = 0.255768607007
# Female GPA mean = 3.12481778824
# Female GPA std = 0.227523205473

# %%
##Percentage of women in class vs. performance

x = gender['female']
y = gfemale.fillna(0)

plt.plot(x,y,'.')

from scipy import stats
a= stats.linregress(x,y)
print "slope: ", a[0]
print "intercept: ", a[1]
print "r - value: ", a[2]
print "p - value: ", a[3]
print "stderr: ", a[4]
# Out:
# slope:  2.53409961063
# intercept:  1.78082685353
# r - value:  0.425763370031
# p - value:  2.32513800554e-05
# stderr:  0.567679622772

# %% [markdown]
# ### SPRING TERM

# %%
#Spring Only
spring = data.ix[data['termdescrshort'].str.contains("SP")]
Class = spring.ix[spring['catalognbr']==number]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =25)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist()
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.649287
# female    0.350713
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.876018
# mean_grade_female    2.748924
# dtype: float64
# Male Grade mean = 2.87601782143
# Male Grade std = 0.518111836999
# Female Grade mean = 2.74892418519
# Female Grade std = 0.512220071827
# Average Difference Across time: 0.0560594615385
# STD  0.65220061218

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .3)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5)
fgpa.hist(bins=15,alpha=.5)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 2.99593464286
# Male GPA std = 0.388839462546
# Female GPA mean = 3.05949785185
# Female GPA std = 0.255718222517
# Male GPA mean = 3.00664992857
# Male GPA std = 0.385548618695
# Female GPA mean = 3.09047474074
# Female GPA std = 0.260302585999

# %% [markdown]
# ### FALL AND WINTER

# %%
#Fall Winter only
FW = data.ix[data['termdescrshort'].str.contains("FA|WN")]
FW1 = FW.ix[FW['catalognbr'] == number]

thr = 350 #threshold for steady enrollment
Class = FW1.ix[FW1['total_students'] > thr]

#Enrollment
Class['total_students'].plot()

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()


##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 


##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =15,alpha=.5)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()


#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()

diff.hist(alpha=.5)
print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.775805
# female    0.224195
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.815411
# mean_grade_female    2.643517
# dtype: float64
# Male Grade mean = 2.8154106
# Male Grade std = 0.111784832159
# Female Grade mean = 2.64351735
# Female Grade std = 0.148231476264
# Average Difference Across time: 0.17189325
# STD  0.118003795907

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()

GPA.mean()

#GPA distribution over time
#mgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_male']
#fgpa = data.ix[data['catalognbr']==140,'mean_cumgpa_female']
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15, alpha =.5)
fgpa.hist(bins=15, alpha= .5)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()


#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()


#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15,alpha=.5,label='Male')
fgpa.hist(bins=15,alpha=.5,label='Male')
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 3.12388925
# Male GPA std = 0.0623953913521
# Female GPA mean = 3.1397043
# Female GPA std = 0.10049137777
# Male GPA mean = 3.1561068
# Male GPA std = 0.0669017700337
# Female GPA mean = 3.1861252
# Female GPA std = 0.100251903383
