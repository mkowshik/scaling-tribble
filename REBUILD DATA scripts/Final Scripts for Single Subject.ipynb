# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# %%
path = '/Users/Manoj/Dropbox/Thesis/Data/REBUILD data/Subjects/CHEM.tab'
data = pd.read_table(path,sep = None)
# Out:
# Using Python parser to sniff delimiter

# %%
number =     130

# %% [markdown]
# ### Run desired data set

# %%
Class = data.ix[data['catalognbr'] == number]

#Enrollment

Class['total_students'].plot()

# %%
#Spring Only
spring = data.ix[data['termdescrshort'].str.contains("SP")]
Class = spring.ix[spring['catalognbr']==number]

#Enrollment
Class['total_students'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-6ef0087c45a6> in <module>()
#       4
#       5 #Enrollment
# ----> 6 Class['total_students'].plot()
#
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    1827                      secondary_y=secondary_y, **kwds)
#    1828
# -> 1829     plot_obj.generate()
#    1830     plot_obj.draw()
#    1831
#
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     901     def generate(self):
#     902         self._args_adjust()
# --> 903         self._compute_plot_data()
#     904         self._setup_subplots()
#     905         self._make_plot()
#
# /Users/Manoj/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#     982         if is_empty:
#     983             raise TypeError('Empty {0!r}: no numeric data to '
# --> 984                             'plot'.format(numeric_data.__class__.__name__))
#     985
#     986         self.data = numeric_data
#
# TypeError: Empty 'Series': no numeric data to plot

# %%
#Fall Winter only
FW = data.ix[data['termdescrshort'].str.contains("FA|WN")]
Class = FW.ix[FW['catalognbr'] == number]

#thr = #threshold for steady enrollment
#Class = FW1.ix[FW1['total_students'] > thr]

#Enrollment
Class['total_students'].plot()

# %% [markdown]
# # Gender

# %%
#gender makeup of class
gender = Class[['male','female']]
gender.plot(title='Gender Fractions vs. time')
print 'mean ='
print gender.mean()
gender.hist()

##Grades in class
grades = Class[['mean_grade_male','mean_grade_female']]
grades[grades == 0] = NaN
grades.plot(title='Final Grade vs. Time')
plt.show()

print '*Mean Grades*: '
print grades.mean() 

##Grade distribution over time
gmale = grades['mean_grade_male']
gfemale =  grades['mean_grade_female']
gmale.hist(bins=25)
#plt.xlim(1.5,4)

#plt.show()

gfemale.hist(bins =25)
plt.title('Male and Female Final Grade Distribution')
plt.show()

print 'Male Grade mean =',gmale.mean()
print 'Male Grade std =',gmale.std()
print 'Female Grade mean =',gfemale.mean()
print 'Female Grade std =',gfemale.std()

#Plotting Gender Differences                
diff = gmale - gfemale
diff.plot(title='Difference in Male and female performance in class vs. time')
plt.show()
diff.hist(bins = 15)


print "Average Difference Across time:" ,diff.mean()
print "STD ", diff.std()
# Out:
# mean =
# male      0.368981
# female    0.631019
# dtype: float64
# *Mean Grades*:
# mean_grade_male      2.937371
# mean_grade_female    3.024129
# dtype: float64
# Male Grade mean = 2.93737114286
# Male Grade std = 0.212858490797
# Female Grade mean = 3.02412906667
# Female Grade std = 0.247130060752
# Average Difference Across time: -0.13491
# STD  0.194291438564

# %% [markdown]
# # GPA

# %%
#GPA make up
GPA = Class[['mean_cumgpa_male','mean_cumgpa_female']]
GPA.plot()
plt.show()
GPA.mean()

#GPA distribution over time
mgpa = Class['mean_cumgpa_male']
fgpa = Class['mean_cumgpa_female']
mgpa.hist(bins=15)
fgpa.hist(bins=15)
plt.title('Male and Female final GPA Distribution')
plt.show()

print 'Male GPA mean =',mgpa.mean()
print 'Male GPA std =',mgpa.std()
print 'Female GPA mean =',fgpa.mean()
print 'Female GPA std =',fgpa.std()

#Incoming GPA makeup
nGPA = Class[['mean_ncumgpa_male','mean_ncumgpa_female']]
nGPA.plot()
plt.show()

nGPA.mean()

#GPA distribution over time
mngpa = Class['mean_ncumgpa_male']
fngpa = Class['mean_ncumgpa_female']
mgpa.hist(bins=15)
fgpa.hist(bins=15)
plt.title('Male and Female incoming GPA Distribution')
plt.show()

print 'Male GPA mean =',mngpa.mean()
print 'Male GPA std =',mngpa.std()
print 'Female GPA mean =',fngpa.mean()
print 'Female GPA std =',fngpa.std()
# Out:
# Male GPA mean = 2.89823666667
# Male GPA std = 0.383698039539
# Female GPA mean = 3.14076373333
# Female GPA std = 0.224664899542
# Male GPA mean = 2.90685593333
# Male GPA std = 0.39169967749
# Female GPA mean = 3.15244453333
# Female GPA std = 0.250631564157
